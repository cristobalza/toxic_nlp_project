# %% [markdown]
# # Part 2:
#
# General Overview:
#
# 5. Model Selection
# 6. Ensemble Model Building
# 7. Test Model Results (Demo)
# 8. Deploy

# %%
import numpy as np
import pandas as pd
import re
import calendar

import seaborn as sns
import matplotlib.style as style


import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.cm as cm
# %matplotlib inline

# grid: rgb(240,240,240)
# background: rgb(200,200,200)
style.use('fivethirtyeight')

#viz
import matplotlib.gridspec as gridspec 
import seaborn as sns
# from wordcloud import WordCloud ,STOPWORDS, ImageColorGenerator
# from PIL import Image
# import matplotlib_venn as venn

# %%
# #nlp
# import string
# import re    #for regex
# import nltk
# from nltk.corpus import stopwords # remove useless words or words that do not add value
# from nltk.stem.lancaster import LancasterStemmer # Convert words to the infinitive form - very aggressive transformation.

# import spacy
# from nltk import pos_tag
# from nltk.stem.wordnet import WordNetLemmatizer 
# from nltk.tokenize import word_tokenize
# # Tweet tokenizer does not split at apostophes which is what we want
# from nltk.tokenize import TweetTokenizer

# %%
# Import packages for pre-processing
from sklearn import preprocessing
from sklearn.feature_selection import SelectFromModel
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# Evaluate model performance
from sklearn.metrics import f1_score, precision_score, recall_score, precision_recall_curve, fbeta_score, confusion_matrix
from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve, auc
from sklearn.model_selection import StratifiedKFold, cross_val_score, learning_curve, cross_validate, train_test_split, KFold

# %%
# Import ML algos
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB, BernoulliNB, GaussianNB
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier
from sklearn.calibration import CalibratedClassifierCV # needed to predict_proba for svm family
from sklearn.svm import SVC, LinearSVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.neural_network import MLPClassifier
# from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.preprocessing import StandardScaler
# from sklearn.feature_selection import RFE

# import xgboost as xgb
# import lightgbm as lgb

# %% [markdown]
# From Part 1, we download the cleaned and pre processed training data:

# %%
data_toxic_balanced = pd.read_csv('./data/output/pre_process_data/data_toxic_balanced.csv')
data_severe_toxic_balanced = pd.read_csv('./data/output/pre_process_data/data_severe_toxic_balanced.csv')
data_obscene_balanced = pd.read_csv('./data/output/pre_process_data/data_obscene_balanced.csv')
data_threat_balanced = pd.read_csv('./data/output/pre_process_data/data_threat_balanced.csv')
data_insult_balanced = pd.read_csv('./data/output/pre_process_data/data_insult_balanced.csv')
data_id_hate_balanced = pd.read_csv('./data/output/pre_process_data/data_id_hate_balanced.csv')

# %% [markdown]
# ## 5. Model Selection
#
# I will use Cross-Validation to select the best model.

# %%
cv = StratifiedKFold(10, shuffle=True, random_state=42)

# %%
# Base model
lr = LogisticRegression(solver='lbfgs', max_iter=100)
# lr.fit(X_train_cv1, y_train)

# Base Model too. Inspire in this class semester
knn = KNeighborsClassifier(n_neighbors=5)

# ARGUABLY the best one vs all
svm_model = LinearSVC()
svm_model_2 = CalibratedClassifierCV(svm_model)

# Standard powerful model
randomforest = RandomForestClassifier(n_estimators=100, random_state=42)

# I had good past experience with this one
gb = GradientBoostingClassifier(random_state=42)

# Base Neural Network
mlp = MLPClassifier(random_state=42)

# Microsoft ALg
# lg = lgb.LGBMClassifier(max_bin=4,
#                     num_iterations=550,
#                     learning_rate=0.0114,
#                     max_depth=3,
#                     num_leaves=7,
#                     colsample_bytree=0.35,
#                     random_state=42,
#                     n_jobs=-1)


# xg = xgb.XGBClassifier(
#     n_estimators=2800,
#     min_child_weight=0.1,
#     learning_rate=0.002,
#     max_depth=2,
#     subsample=0.47,
#     colsample_bytree=0.35,
#     gamma=0.4,
#     reg_lambda=0.4,
#     random_state=42,
#     n_jobs=-1,
# )

# %%
estimators = [lr,
             knn,
             svm_model_2,
             randomforest,
             gb,
             mlp
#               lg,
#               xg
             ]

# %%
def cv_tf_train_test(df_done,label,vectorizer,ngram):

    # Split the data into X and y data sets
    X = df_done.comment_text
    y = df_done[label]

    # Split our data into training and test data 
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

    # Create a Vectorizer object and remove stopwords from the table
    cv1 = vectorizer(ngram_range=(ngram), stop_words='english')
    
    X_train_cv1 = cv1.fit_transform(X_train) # Learn the vocabulary dictionary and return term-document matrix
    X_test_cv1  = cv1.transform(X_test)      # Learn a vocabulary dictionary of all tokens in the raw documents.
    
    # Output a Dataframe of the CountVectorizer with unique words as the labels
    # test = pd.DataFrame(X_train_cv1.toarray(), columns=cv1.get_feature_names())
    # Step 1 : Create an empty DataFrame and a row_index counting variable
    model_df = pd.DataFrame()
    row_index_count = 0

    for est in estimators:
        # With the row index, input the name of the current Model
        model_df.loc[row_index_count, 'Model Name'] = est.__class__.__name__
        # Step 2 : Create a Cross-Validated Object using `cross_validate` from Sklearn 
        cv_results = cross_validate(
            est,
            X_train_cv1,
            y_train,
            cv=cv,
            scoring='f1',
            return_train_score=True,
            n_jobs=-1
        )
        # Input the F1 Score of prediction of each column
        model_df.loc[row_index_count, 'F1 Score'] = cv_results['train_score'].mean()
        row_index_count = row_index_count + 1
        
    # Step 3 : sort the DataFrame values by the F1 Score
    model_df.sort_values(by=['F1 Score'],
                            ascending=False,
                            inplace=True)
    
    return model_df

# %%
import time

t0 = time.time()

df_tox_cv = cv_tf_train_test(data_toxic_balanced, 'toxic', TfidfVectorizer, (1,1))
df_tox_cv.rename(columns={'F1 Score': 'F1 Score(toxic)'}, inplace=True)

t1 = time.time()

total = 'Time taken: {} seconds'.format(t1-t0)
print(total)

df_tox_cv
# Out:
# Time taken: 854.6177761554718 seconds
#                    Model Name  F1 Score(toxic)
# 3      RandomForestClassifier         0.999711
# 5               MLPClassifier         0.999711
# 2      CalibratedClassifierCV         0.996939
# 0          LogisticRegression         0.947215
# 4  GradientBoostingClassifier         0.807415
# 1        KNeighborsClassifier         0.729866
# 6              LGBMClassifier         0.723090
# 7               XGBClassifier         0.692374

# %%
t0 = time.time()

df_sev_cv = cv_tf_train_test(data_severe_toxic_balanced, 'severe_toxic', TfidfVectorizer, (1,1))
df_sev_cv.rename(columns={'F1 Score': 'F1 Score(severe_toxic)'}, inplace=True)

t1 = time.time()

total = 'Time taken: {} seconds'.format(t1-t0)
print(total)
df_sev_cv
# Out:
# Time taken: 169.86274313926697 seconds
#                    Model Name  F1 Score(severe_toxic)
# 3      RandomForestClassifier                0.999551
# 5               MLPClassifier                0.998903
# 2      CalibratedClassifierCV                0.996462
# 0          LogisticRegression                0.969083
# 4  GradientBoostingClassifier                0.936072
# 6              LGBMClassifier                0.903036
# 7               XGBClassifier                0.869159
# 1        KNeighborsClassifier                0.711469

# %%
t0 = time.time()

df_obs_cv = cv_tf_train_test(data_obscene_balanced, 'obscene', TfidfVectorizer, (1,1))
df_obs_cv.rename(columns={'F1 Score': 'F1 Score(obscene)'}, inplace=True)

t1 = time.time()

total = 'Time taken: {} seconds'.format(t1-t0)
print(total)

df_obs_cv
# Out:
# Time taken: 827.1422989368439 seconds
#                    Model Name  F1 Score(obscene)
# 3      RandomForestClassifier           0.999856
# 5               MLPClassifier           0.999278
# 2      CalibratedClassifierCV           0.997419
# 0          LogisticRegression           0.956692
# 4  GradientBoostingClassifier           0.880880
# 6              LGBMClassifier           0.836955
# 7               XGBClassifier           0.797823
# 1        KNeighborsClassifier           0.690330

# %%
t0 = time.time()

df_thr_cv = cv_tf_train_test(data_threat_balanced, 'threat', TfidfVectorizer, (1,1))
df_thr_cv.rename(columns={'F1 Score': 'F1 Score(threat)'}, inplace=True)

t1 = time.time()

total = 'Time taken: {} seconds'.format(t1-t0)
print(total)

df_thr_cv
# Out:
# Time taken: 106.33558392524719 seconds
#                    Model Name  F1 Score(threat)
# 3      RandomForestClassifier          1.000000
# 5               MLPClassifier          1.000000
# 2      CalibratedClassifierCV          0.999828
# 4  GradientBoostingClassifier          0.945889
# 1        KNeighborsClassifier          0.834564
# 6              LGBMClassifier          0.809115
# 7               XGBClassifier          0.778239
# 0          LogisticRegression          0.767986

# %%
t0 = time.time()

df_ins_cv = cv_tf_train_test(data_insult_balanced, 'insult', TfidfVectorizer, (1,1))
df_ins_cv.rename(columns={'F1 Score': 'F1 Score(insult)'}, inplace=True)

t1 = time.time()

total = 'Time taken: {} seconds'.format(t1-t0)
print(total)

df_ins_cv
# Out:
# Time taken: 924.4053530693054 seconds
#                    Model Name  F1 Score(insult)
# 3      RandomForestClassifier          0.999439
# 5               MLPClassifier          0.999294
# 2      CalibratedClassifierCV          0.993415
# 0          LogisticRegression          0.952480
# 1        KNeighborsClassifier          0.869914
# 4  GradientBoostingClassifier          0.850832
# 6              LGBMClassifier          0.791688
# 7               XGBClassifier          0.748446

# %%
t0 = time.time()

df_ide_cv = cv_tf_train_test(data_id_hate_balanced, 'identity_hate', TfidfVectorizer, (1,1))
df_ide_cv.rename(columns={'F1 Score': 'F1 Score(identity_hate)'}, inplace=True)

t1 = time.time()

total = 'Time taken: {} seconds'.format(t1-t0)
print(total)

df_ide_cv
# Out:
# Time taken: 558.8539710044861 seconds
#                    Model Name  F1 Score(identity_hate)
# 3      RandomForestClassifier                 0.999079
# 5               MLPClassifier                 0.998616
# 2      CalibratedClassifierCV                 0.989713
# 1        KNeighborsClassifier                 0.912527
# 4  GradientBoostingClassifier                 0.808305
# 0          LogisticRegression                 0.767211
# 6              LGBMClassifier                 0.713482
# 7               XGBClassifier                 0.649222

# %%
# # Let's combine the dataframes into a master dataframe to compare F1 scores across all categories.
# f1_all = pd.concat([df_tox_cv, df_sev_cv, df_obs_cv, df_ins_cv, df_thr_cv, df_ide_cv], axis=1)
# f1_all
# Out:
#                    Model Name  F1 Score(toxic)                  Model Name  \
# 0          LogisticRegression         0.947215          LogisticRegression
# 1        KNeighborsClassifier         0.729866        KNeighborsClassifier
# 2      CalibratedClassifierCV         0.996939      CalibratedClassifierCV
# 3      RandomForestClassifier         0.999711      RandomForestClassifier
# 4  GradientBoostingClassifier         0.807415  GradientBoostingClassifier
# 5               MLPClassifier         0.999711               MLPClassifier
# 6              LGBMClassifier         0.723090              LGBMClassifier
# 7               XGBClassifier         0.692374               XGBClassifier
#
#    F1 Score(severe_toxic)                  Model Name  F1 Score(obscene)  \
# 0                0.969083          LogisticRegression           0.956692
# 1                0.711469        KNeighborsClassifier           0.690330
# 2                0.996462      CalibratedClassifierCV           0.997419
# 3                0.999551      RandomForestClassifier           0.999856
# 4                0.936072  GradientBoostingClassifier           0.880880
# 5                0.998903               MLPClassifier           0.999278
# 6                0.903036              LGBMClassifier           0.836955
# 7                0.869159               XGBClassifier           0.797823
#
#                    Model Name  F1 Score(insult)                  Model Name  \
# 0          LogisticRegression          0.952480          LogisticRegression
# 1        KNeighborsClassifier          0.869914        KNeighborsClassifier
# 2      CalibratedClassifierCV          0.993415      CalibratedClassifierCV
# 3      RandomForestClassifier          0.999439      RandomForestClassifier
# 4  GradientBoostingClassifier          0.850832  GradientBoostingClassifier
# 5               MLPClassifier          0.999294               MLPClassifier
# 6              LGBMClassifier          0.791688              LGBMClassifier
# 7               XGBClassifier          0.748446               XGBClassifier
#
#    F1 Score(threat)                  Model Name  F1 Score(identity_hate)
# 0          0.767986          LogisticRegression                 0.767211
# 1          0.834564        KNeighborsClassifier                 0.912527
# 2          0.999828      CalibratedClassifierCV                 0.989713
# 3          1.000000      RandomForestClassifier                 0.999079
# 4          0.945889  GradientBoostingClassifier                 0.808305
# 5          1.000000               MLPClassifier                 0.998616
# 6          0.809115              LGBMClassifier                 0.713482
# 7          0.778239               XGBClassifier                 0.649222

# %%
def train_test_func(df_done,label,vectorizer,ngram):

    # Split the data into X and y data sets
    X = df_done.comment_text
    y = df_done[label]

    # Split our data into training and test data 
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)


    # Create a Vectorizer object and remove stopwords from the table
    cv1 = vectorizer(ngram_range=(ngram), stop_words='english')
    
    X_train_cv1 = cv1.fit_transform(X_train) # Learn the vocabulary dictionary and return term-document matrix
    X_test_cv1  = cv1.transform(X_test)      # Learn a vocabulary dictionary of all tokens in the raw documents.
    
    
    # Step 1 : Create an empty DataFrame and a row_index counting variable
    model_df = pd.DataFrame()

    for est in estimators:
        est.fit(X_train_cv1, y_train)
        # Input the F1 Score of prediction of each column
        model_df.loc[est.__class__.__name__, 'F1 Score'] = f1_score(est.predict(X_test_cv1), y_test)


    return model_df

# %%
import time

t0 = time.time()

df_tox_cv = train_test_func(data_toxic_balanced, 'toxic', TfidfVectorizer, (1,1))
df_tox_cv.rename(columns={'F1 Score': 'F1 Score(toxic)'}, inplace=True)

t1 = time.time()

total = 'Time taken: {} seconds'.format(t1-t0)
print(total)

df_tox_cv
# Out:
# /Users/cristobalza/opt/anaconda3/lib/python3.7/site-packages/lightgbm/engine.py:148: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# Time taken: 122.32051110267639 seconds
#                             F1 Score(toxic)
# LogisticRegression                 0.856949
# KNeighborsClassifier               0.265477
# CalibratedClassifierCV             0.867286
# RandomForestClassifier             0.833915
# GradientBoostingClassifier         0.777610
# MLPClassifier                      0.848902
# LGBMClassifier                     0.712306
# XGBClassifier                      0.673435

# %%
t0 = time.time()

df_sev_cv = train_test_func(data_severe_toxic_balanced, 'severe_toxic', TfidfVectorizer, (1,1))
df_sev_cv.rename(columns={'F1 Score': 'F1 Score(severe_toxic)'}, inplace=True)

t1 = time.time()

total = 'Time taken: {} seconds'.format(t1-t0)
print(total)
df_sev_cv
# Out:
# /Users/cristobalza/opt/anaconda3/lib/python3.7/site-packages/lightgbm/engine.py:148: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# Time taken: 26.188308000564575 seconds
#                             F1 Score(severe_toxic)
# LogisticRegression                        0.917211
# KNeighborsClassifier                      0.673669
# CalibratedClassifierCV                    0.936306
# RandomForestClassifier                    0.896552
# GradientBoostingClassifier                0.887133
# MLPClassifier                             0.919087
# LGBMClassifier                            0.883616
# XGBClassifier                             0.842723

# %%
t0 = time.time()

df_obs_cv = train_test_func(data_obscene_balanced, 'obscene', TfidfVectorizer, (1,1))
df_obs_cv.rename(columns={'F1 Score': 'F1 Score(obscene)'}, inplace=True)

t1 = time.time()

total = 'Time taken: {} seconds'.format(t1-t0)
print(total)

df_obs_cv
# Out:
# /Users/cristobalza/opt/anaconda3/lib/python3.7/site-packages/lightgbm/engine.py:148: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# Time taken: 130.47240805625916 seconds
#                             F1 Score(obscene)
# LogisticRegression                   0.904828
# KNeighborsClassifier                 0.687290
# CalibratedClassifierCV               0.928217
# RandomForestClassifier               0.889993
# GradientBoostingClassifier           0.872976
# MLPClassifier                        0.880026
# LGBMClassifier                       0.845353
# XGBClassifier                        0.806626

# %%
t0 = time.time()

df_thr_cv = train_test_func(data_threat_balanced, 'threat', TfidfVectorizer, (1,1))
df_thr_cv.rename(columns={'F1 Score': 'F1 Score(threat)'}, inplace=True)

t1 = time.time()

total = 'Time taken: {} seconds'.format(t1-t0)
print(total)

df_thr_cv
# Out:
# /Users/cristobalza/opt/anaconda3/lib/python3.7/site-packages/lightgbm/engine.py:148: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# Time taken: 19.13904118537903 seconds
#                             F1 Score(threat)
# LogisticRegression                  0.710744
# KNeighborsClassifier                0.751938
# CalibratedClassifierCV              0.906040
# RandomForestClassifier              0.850000
# GradientBoostingClassifier          0.791367
# MLPClassifier                       0.864111
# LGBMClassifier                      0.764479
# XGBClassifier                       0.712000

# %%
t0 = time.time()

df_ins_cv = train_test_func(data_insult_balanced, 'insult', TfidfVectorizer, (1,1))
df_ins_cv.rename(columns={'F1 Score': 'F1 Score(insult)'}, inplace=True)

t1 = time.time()

total = 'Time taken: {} seconds'.format(t1-t0)
print(total)

df_ins_cv
# Out:
# /Users/cristobalza/opt/anaconda3/lib/python3.7/site-packages/lightgbm/engine.py:148: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# Time taken: 138.65218877792358 seconds
#                             F1 Score(insult)
# LogisticRegression                  0.893501
# KNeighborsClassifier                0.817460
# CalibratedClassifierCV              0.904935
# RandomForestClassifier              0.872291
# GradientBoostingClassifier          0.837312
# MLPClassifier                       0.869908
# LGBMClassifier                      0.792178
# XGBClassifier                       0.749800

# %%
t0 = time.time()

df_ide_cv = train_test_func(data_id_hate_balanced, 'identity_hate', TfidfVectorizer, (1,1))
df_ide_cv.rename(columns={'F1 Score': 'F1 Score(identity_hate)'}, inplace=True)

t1 = time.time()

total = 'Time taken: {} seconds'.format(t1-t0)
print(total)

df_ide_cv
# Out:
# /Users/cristobalza/opt/anaconda3/lib/python3.7/site-packages/lightgbm/engine.py:148: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# Time taken: 87.21114325523376 seconds
#                             F1 Score(identity_hate)
# LogisticRegression                         0.689266
# KNeighborsClassifier                       0.673913
# CalibratedClassifierCV                     0.819712
# RandomForestClassifier                     0.776840
# GradientBoostingClassifier                 0.705722
# MLPClassifier                              0.779343
# LGBMClassifier                             0.666667
# XGBClassifier                              0.610015

# %%
# Let's combine the dataframes into a master dataframe to compare F1 scores across all categories.
f1_all = pd.concat([df_tox_cv, df_sev_cv, df_obs_cv, df_ins_cv, df_thr_cv, df_ide_cv], axis=1)
f1_all.style.background_gradient(cmap='Reds')
# Out:
# <style  type="text/css" >
#     #T_a0c458da_378e_11eb_94a3_f2189821d74crow0_col0 {
#             background-color:  #6f020e;
#             color:  #f1f1f1;
#         }    #T_a0c458da_378e_11eb_94a3_f2189821d74crow0_col1 {
#             background-color:  #8a0812;
#             color:  #f1f1f1;
#         }    #T_a0c458da_378e_11eb_94a3_f2189821d74crow0_col2 {
#             background-color:  #960b13;
#             color:  #f1f1f1;
#         }    #T_a0c458da_378e_11eb_94a3_f2189821d74crow0_col3 {
#             background-color:  #8a0812;
#             color:  #f1f1f1;
#         }    #T_a0c458da_378e_11eb_94a3_f2189821d74crow0_col4 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_a0c458da_378e_11eb_94a3_f2189821d74crow0_col5 {
#             background-color:  #fc9272;
#             color:  #000000;
#         }    #T_a0c458da_378e_11eb_94a3_f2189821d74crow1_col0 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_a0c458da_378e_11eb_94a3_f2189821d74crow1_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_a0c458da_378e_11eb_94a3_f2189821d74crow1_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_a0c458da_378e_11eb_94a3_f2189821d74crow1_col3 {
#             background-color:  #fc7f5f;
#             color:  #000000;
#         }    #T_a0c458da_378e_11eb_94a3_f2189821d74crow1_col4 {
#             background-color:  #fdc7b2;
#             color:  #000000;
#         }    #T_a0c458da_378e_11eb_94a3_f2189821d74crow1_col5 {
#             background-color:  #fca98c;
#             color:  #000000;
#         }    #T_a0c458da_378e_11eb_94a3_f2189821d74crow2_col0 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_a0c458da_378e_11eb_94a3_f2189821d74crow2_col1 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_a0c458da_378e_11eb_94a3_f2189821d74crow2_col2 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_a0c458da_378e_11eb_94a3_f2189821d74crow2_col3 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_a0c458da_378e_11eb_94a3_f2189821d74crow2_col4 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_a0c458da_378e_11eb_94a3_f2189821d74crow2_col5 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_a0c458da_378e_11eb_94a3_f2189821d74crow3_col0 {
#             background-color:  #820711;
#             color:  #f1f1f1;
#         }    #T_a0c458da_378e_11eb_94a3_f2189821d74crow3_col1 {
#             background-color:  #ac1117;
#             color:  #f1f1f1;
#         }    #T_a0c458da_378e_11eb_94a3_f2189821d74crow3_col2 {
#             background-color:  #af1117;
#             color:  #f1f1f1;
#         }    #T_a0c458da_378e_11eb_94a3_f2189821d74crow3_col3 {
#             background-color:  #be151a;
#             color:  #f1f1f1;
#         }    #T_a0c458da_378e_11eb_94a3_f2189821d74crow3_col4 {
#             background-color:  #d52221;
#             color:  #f1f1f1;
#         }    #T_a0c458da_378e_11eb_94a3_f2189821d74crow3_col5 {
#             background-color:  #bd151a;
#             color:  #f1f1f1;
#         }    #T_a0c458da_378e_11eb_94a3_f2189821d74crow4_col0 {
#             background-color:  #ac1117;
#             color:  #f1f1f1;
#         }    #T_a0c458da_378e_11eb_94a3_f2189821d74crow4_col1 {
#             background-color:  #b71319;
#             color:  #f1f1f1;
#         }    #T_a0c458da_378e_11eb_94a3_f2189821d74crow4_col2 {
#             background-color:  #c4161c;
#             color:  #f1f1f1;
#         }    #T_a0c458da_378e_11eb_94a3_f2189821d74crow4_col3 {
#             background-color:  #f5523a;
#             color:  #000000;
#         }    #T_a0c458da_378e_11eb_94a3_f2189821d74crow4_col4 {
#             background-color:  #fc8666;
#             color:  #000000;
#         }    #T_a0c458da_378e_11eb_94a3_f2189821d74crow4_col5 {
#             background-color:  #fb7858;
#             color:  #000000;
#         }    #T_a0c458da_378e_11eb_94a3_f2189821d74crow5_col0 {
#             background-color:  #75030f;
#             color:  #f1f1f1;
#         }    #T_a0c458da_378e_11eb_94a3_f2189821d74crow5_col1 {
#             background-color:  #860811;
#             color:  #f1f1f1;
#         }    #T_a0c458da_378e_11eb_94a3_f2189821d74crow5_col2 {
#             background-color:  #bc141a;
#             color:  #f1f1f1;
#         }    #T_a0c458da_378e_11eb_94a3_f2189821d74crow5_col3 {
#             background-color:  #c3161b;
#             color:  #f1f1f1;
#         }    #T_a0c458da_378e_11eb_94a3_f2189821d74crow5_col4 {
#             background-color:  #bf151b;
#             color:  #f1f1f1;
#         }    #T_a0c458da_378e_11eb_94a3_f2189821d74crow5_col5 {
#             background-color:  #b91419;
#             color:  #f1f1f1;
#         }    #T_a0c458da_378e_11eb_94a3_f2189821d74crow6_col0 {
#             background-color:  #cc191e;
#             color:  #f1f1f1;
#         }    #T_a0c458da_378e_11eb_94a3_f2189821d74crow6_col1 {
#             background-color:  #bc141a;
#             color:  #f1f1f1;
#         }    #T_a0c458da_378e_11eb_94a3_f2189821d74crow6_col2 {
#             background-color:  #e63328;
#             color:  #f1f1f1;
#         }    #T_a0c458da_378e_11eb_94a3_f2189821d74crow6_col3 {
#             background-color:  #fcb499;
#             color:  #000000;
#         }    #T_a0c458da_378e_11eb_94a3_f2189821d74crow6_col4 {
#             background-color:  #fcb398;
#             color:  #000000;
#         }    #T_a0c458da_378e_11eb_94a3_f2189821d74crow6_col5 {
#             background-color:  #fcb499;
#             color:  #000000;
#         }    #T_a0c458da_378e_11eb_94a3_f2189821d74crow7_col0 {
#             background-color:  #e02c26;
#             color:  #f1f1f1;
#         }    #T_a0c458da_378e_11eb_94a3_f2189821d74crow7_col1 {
#             background-color:  #ea362a;
#             color:  #f1f1f1;
#         }    #T_a0c458da_378e_11eb_94a3_f2189821d74crow7_col2 {
#             background-color:  #fb6c4c;
#             color:  #000000;
#         }    #T_a0c458da_378e_11eb_94a3_f2189821d74crow7_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_a0c458da_378e_11eb_94a3_f2189821d74crow7_col4 {
#             background-color:  #fff4ef;
#             color:  #000000;
#         }    #T_a0c458da_378e_11eb_94a3_f2189821d74crow7_col5 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }</style><table id="T_a0c458da_378e_11eb_94a3_f2189821d74c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >F1 Score(toxic)</th>        <th class="col_heading level0 col1" >F1 Score(severe_toxic)</th>        <th class="col_heading level0 col2" >F1 Score(obscene)</th>        <th class="col_heading level0 col3" >F1 Score(insult)</th>        <th class="col_heading level0 col4" >F1 Score(threat)</th>        <th class="col_heading level0 col5" >F1 Score(identity_hate)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a0c458da_378e_11eb_94a3_f2189821d74clevel0_row0" class="row_heading level0 row0" >LogisticRegression</th>
#                         <td id="T_a0c458da_378e_11eb_94a3_f2189821d74crow0_col0" class="data row0 col0" >0.856949</td>
#                         <td id="T_a0c458da_378e_11eb_94a3_f2189821d74crow0_col1" class="data row0 col1" >0.917211</td>
#                         <td id="T_a0c458da_378e_11eb_94a3_f2189821d74crow0_col2" class="data row0 col2" >0.904828</td>
#                         <td id="T_a0c458da_378e_11eb_94a3_f2189821d74crow0_col3" class="data row0 col3" >0.893501</td>
#                         <td id="T_a0c458da_378e_11eb_94a3_f2189821d74crow0_col4" class="data row0 col4" >0.710744</td>
#                         <td id="T_a0c458da_378e_11eb_94a3_f2189821d74crow0_col5" class="data row0 col5" >0.689266</td>
#             </tr>
#             <tr>
#                         <th id="T_a0c458da_378e_11eb_94a3_f2189821d74clevel0_row1" class="row_heading level0 row1" >KNeighborsClassi

# %%
sns.lineplot(data=f1_all.transpose(), markers=True)
plt.xticks(rotation='60', fontsize=14)
plt.yticks(fontsize=14)
plt.legend(loc='best')
plt.title('F1 Score of ML models (TF-IDF)', fontsize=18);

# Repeat this for CountVectorizer as well

# %% [markdown]
# ##### CountVectorize

# %%
import time

t0 = time.time()

df_tox_cv = train_test_func(data_toxic_balanced, 'toxic', CountVectorizer, (1,1))
df_tox_cv.rename(columns={'F1 Score': 'F1 Score(toxic)'}, inplace=True)

t1 = time.time()

total = 'Time taken: {} seconds'.format(t1-t0)
print(total)

df_tox_cv
# Out:
# /Users/cristobalza/opt/anaconda3/envs/santiago-projects/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Time taken: 117.2593321800232 seconds
#                             F1 Score(toxic)
# LogisticRegression                 0.863636
# KNeighborsClassifier               0.707617
# CalibratedClassifierCV             0.657827
# RandomForestClassifier             0.831642
# GradientBoostingClassifier         0.765044
# MLPClassifier                      0.855263

# %%
t0 = time.time()

df_sev_cv = train_test_func(data_severe_toxic_balanced, 'severe_toxic', CountVectorizer, (1,1))
df_sev_cv.rename(columns={'F1 Score': 'F1 Score(severe_toxic)'}, inplace=True)

t1 = time.time()

total = 'Time taken: {} seconds'.format(t1-t0)
print(total)
df_sev_cv
# Out:
# Time taken: 19.61151623725891 seconds
#                             F1 Score(severe_toxic)
# LogisticRegression                        0.935622
# KNeighborsClassifier                      0.741270
# CalibratedClassifierCV                    0.628734
# RandomForestClassifier                    0.906344
# GradientBoostingClassifier                0.889888
# MLPClassifier                             0.927772

# %%
t0 = time.time()

df_obs_cv = train_test_func(data_obscene_balanced, 'obscene', CountVectorizer, (1,1))
df_obs_cv.rename(columns={'F1 Score': 'F1 Score(obscene)'}, inplace=True)

t1 = time.time()

total = 'Time taken: {} seconds'.format(t1-t0)
print(total)

df_obs_cv
# Out:
# /Users/cristobalza/opt/anaconda3/envs/santiago-projects/lib/python3.7/site-packages/sklearn/svm/_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/cristobalza/opt/anaconda3/envs/santiago-projects/lib/python3.7/site-packages/sklearn/svm/_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/cristobalza/opt/anaconda3/envs/santiago-projects/lib/python3.7/site-packages/sklearn/svm/_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Time taken: 104.19719696044922 seconds
#                             F1 Score(obscene)
# LogisticRegression                   0.922196
# KNeighborsClassifier                 0.758436
# CalibratedClassifierCV               0.565440
# RandomForestClassifier               0.898243
# GradientBoostingClassifier           0.870069
# MLPClassifier                        0.902973

# %%
t0 = time.time()

df_thr_cv = train_test_func(data_threat_balanced, 'threat', CountVectorizer, (1,1))
df_thr_cv.rename(columns={'F1 Score': 'F1 Score(threat)'}, inplace=True)

t1 = time.time()

total = 'Time taken: {} seconds'.format(t1-t0)
print(total)

df_thr_cv
# Out:
# Time taken: 11.462177038192749 seconds
#                             F1 Score(threat)
# LogisticRegression                  0.839858
# KNeighborsClassifier                0.641667
# CalibratedClassifierCV              0.086420
# RandomForestClassifier              0.867133
# GradientBoostingClassifier          0.784615
# MLPClassifier                       0.882155

# %%
t0 = time.time()

df_ins_cv = train_test_func(data_insult_balanced, 'insult', CountVectorizer, (1,1))
df_ins_cv.rename(columns={'F1 Score': 'F1 Score(insult)'}, inplace=True)

t1 = time.time()

total = 'Time taken: {} seconds'.format(t1-t0)
print(total)

df_ins_cv
# Out:
# /Users/cristobalza/opt/anaconda3/envs/santiago-projects/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /Users/cristobalza/opt/anaconda3/envs/santiago-projects/lib/python3.7/site-packages/sklearn/svm/_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/cristobalza/opt/anaconda3/envs/santiago-projects/lib/python3.7/site-packages/sklearn/svm/_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/cristobalza/opt/anaconda3/envs/santiago-projects/lib/python3.7/site-packages/sklearn/svm/_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Time taken: 107.986163854599 seconds
#                             F1 Score(insult)
# LogisticRegression                  0.896900
# KNeighborsClassifier                0.786018
# CalibratedClassifierCV              0.726754
# RandomForestClassifier              0.870383
# GradientBoostingClassifier          0.838165
# MLPClassifier                       0.878927

# %%
t0 = time.time()

df_ide_cv = train_test_func(data_id_hate_balanced, 'identity_hate', CountVectorizer, (1,1))
df_ide_cv.rename(columns={'F1 Score': 'F1 Score(identity_hate)'}, inplace=True)

t1 = time.time()

total = 'Time taken: {} seconds'.format(t1-t0)
print(total)

df_ide_cv
# Out:
# /Users/cristobalza/opt/anaconda3/envs/santiago-projects/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Time taken: 64.36963105201721 seconds
#                             F1 Score(identity_hate)
# LogisticRegression                         0.772959
# KNeighborsClassifier                       0.640212
# CalibratedClassifierCV                     0.052863
# RandomForestClassifier                     0.769231
# GradientBoostingClassifier                 0.685083
# MLPClassifier                              0.783555

# %%
# Let's combine the dataframes into a master dataframe to compare F1 scores across all categories.
f1_all = pd.concat([df_tox_cv, df_sev_cv, df_obs_cv, df_ins_cv, df_thr_cv, df_ide_cv], axis=1)
f1_all.style.background_gradient(cmap='Reds')
# Out:
# <style  type="text/css" >
# #T_ca632132_3791_11eb_bb22_f2189821d74crow0_col0,#T_ca632132_3791_11eb_bb22_f2189821d74crow0_col1,#T_ca632132_3791_11eb_bb22_f2189821d74crow0_col2,#T_ca632132_3791_11eb_bb22_f2189821d74crow0_col3,#T_ca632132_3791_11eb_bb22_f2189821d74crow5_col4,#T_ca632132_3791_11eb_bb22_f2189821d74crow5_col5{
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }#T_ca632132_3791_11eb_bb22_f2189821d74crow0_col4,#T_ca632132_3791_11eb_bb22_f2189821d74crow5_col2{
#             background-color:  #800610;
#             color:  #f1f1f1;
#         }#T_ca632132_3791_11eb_bb22_f2189821d74crow0_col5{
#             background-color:  #6d010e;
#             color:  #f1f1f1;
#         }#T_ca632132_3791_11eb_bb22_f2189821d74crow1_col0{
#             background-color:  #fcbea5;
#             color:  #000000;
#         }#T_ca632132_3791_11eb_bb22_f2189821d74crow1_col1{
#             background-color:  #fc9576;
#             color:  #000000;
#         }#T_ca632132_3791_11eb_bb22_f2189821d74crow1_col2{
#             background-color:  #f75b40;
#             color:  #000000;
#         }#T_ca632132_3791_11eb_bb22_f2189821d74crow1_col3{
#             background-color:  #fc9b7c;
#             color:  #000000;
#         }#T_ca632132_3791_11eb_bb22_f2189821d74crow1_col4{
#             background-color:  #da2723;
#             color:  #f1f1f1;
#         }#T_ca632132_3791_11eb_bb22_f2189821d74crow1_col5{
#             background-color:  #bb141a;
#             color:  #f1f1f1;
#         }#T_ca632132_3791_11eb_bb22_f2189821d74crow2_col0,#T_ca632132_3791_11eb_bb22_f2189821d74crow2_col1,#T_ca632132_3791_11eb_bb22_f2189821d74crow2_col2,#T_ca632132_3791_11eb_bb22_f2189821d74crow2_col3,#T_ca632132_3791_11eb_bb22_f2189821d74crow2_col4,#T_ca632132_3791_11eb_bb22_f2189821d74crow2_col5{
#             background-color:  #fff5f0;
#             color:  #000000;
#         }#T_ca632132_3791_11eb_bb22_f2189821d74crow3_col0,#T_ca632132_3791_11eb_bb22_f2189821d74crow3_col3{
#             background-color:  #ad1117;
#             color:  #f1f1f1;
#         }#T_ca632132_3791_11eb_bb22_f2189821d74crow3_col1{
#             background-color:  #960b13;
#             color:  #f1f1f1;
#         }#T_ca632132_3791_11eb_bb22_f2189821d74crow3_col2{
#             background-color:  #880811;
#             color:  #f1f1f1;
#         }#T_ca632132_3791_11eb_bb22_f2189821d74crow3_col4{
#             background-color:  #6f020e;
#             color:  #f1f1f1;
#         }#T_ca632132_3791_11eb_bb22_f2189821d74crow3_col5{
#             background-color:  #71020e;
#             color:  #f1f1f1;
#         }#T_ca632132_3791_11eb_bb22_f2189821d74crow4_col0{
#             background-color:  #f96245;
#             color:  #000000;
#         }#T_ca632132_3791_11eb_bb22_f2189821d74crow4_col1{
#             background-color:  #ac1117;
#             color:  #f1f1f1;
#         }#T_ca632132_3791_11eb_bb22_f2189821d74crow4_col2{
#             background-color:  #ab1016;
#             color:  #f1f1f1;
#         }#T_ca632132_3791_11eb_bb22_f2189821d74crow4_col3{
#             background-color:  #e63328;
#             color:  #f1f1f1;
#         }#T_ca632132_3791_11eb_bb22_f2189821d74crow4_col4{
#             background-color:  #a30f15;
#             color:  #f1f1f1;
#         }#T_ca632132_3791_11eb_bb22_f2189821d74crow4_col5{
#             background-color:  #a81016;
#             color:  #f1f1f1;
#         }#T_ca632132_3791_11eb_bb22_f2189821d74crow5_col0{
#             background-color:  #7a0510;
#             color:  #f1f1f1;
#         }#T_ca632132_3791_11eb_bb22_f2189821d74crow5_col1{
#             background-color:  #73030f;
#             color:  #f1f1f1;
#         }#T_ca632132_3791_11eb_bb22_f2189821d74crow5_col3{
#             background-color:  #9c0d14;
#             color:  #f1f1f1;
#         }</style><table id="T_ca632132_3791_11eb_bb22_f2189821d74c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >F1 Score(toxic)</th>        <th class="col_heading level0 col1" >F1 Score(severe_toxic)</th>        <th class="col_heading level0 col2" >F1 Score(obscene)</th>        <th class="col_heading level0 col3" >F1 Score(insult)</th>        <th class="col_heading level0 col4" >F1 Score(threat)</th>        <th class="col_heading level0 col5" >F1 Score(identity_hate)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ca632132_3791_11eb_bb22_f2189821d74clevel0_row0" class="row_heading level0 row0" >LogisticRegression</th>
#                         <td id="T_ca632132_3791_11eb_bb22_f2189821d74crow0_col0" class="data row0 col0" >0.863636</td>
#                         <td id="T_ca632132_3791_11eb_bb22_f2189821d74crow0_col1" class="data row0 col1" >0.935622</td>
#                         <td id="T_ca632132_3791_11eb_bb22_f2189821d74crow0_col2" class="data row0 col2" >0.922196</td>
#                         <td id="T_ca632132_3791_11eb_bb22_f2189821d74crow0_col3" class="data row0 col3" >0.896900</td>
#                         <td id="T_ca632132_3791_11eb_bb22_f2189821d74crow0_col4" class="data row0 col4" >0.839858</td>
#                         <td id="T_ca632132_3791_11eb_bb22_f2189821d74crow0_col5" class="data row0 col5" >0.772959</td>
#             </tr>
#             <tr>
#                         <th id="T_ca632132_3791_11eb_bb22_f2189821d74clevel0_row1" class="row_heading level0 row1" >KNeighborsClassifier</th>
#                         <td id="T_ca632132_3791_11eb_bb22_f2189821d74crow1_col0" class="data row1 col0" >0.707617</td>
#                         <td id="T_ca632132_3791_11eb_bb22_f2189821d74crow1_col1" class="data row1 col1" >0.741270</td>
#                         <td id="T_ca632132_3791_11eb_bb22_f2189821d74crow1_col2" class="data row1 col2" >0.758436</td>
#                         <td id="T_ca632132_3791_11eb_bb22_f2189821d74crow1_col3" class="data row1 col3" >0.786018</td>
#                         <td id="T_ca632132_3791_11eb_bb22_f2189821d74crow1_col4" class="data row1 col4" >0.641667</td>
#                         <td id="T_ca632132_3791_11eb_bb22_f2189821d74crow1_col5" class="data row1 col5" >0.640212</td>
#             </tr>
#             <tr>
#                         <th id="T_ca632132_3791_11eb_bb22_f2189821d74clevel0_row2" class="row_heading level0 row2" >CalibratedClassifierCV</th>
#                         <td id="T_ca632132_3791_11eb_bb22_f2189821d74crow2_col0" class="data row2 col0" >0.657827</td>
#                         <td id="T_ca632132_3791_11eb_bb22_f2189821d74crow2_col1" class="data row2 col1" >0.628734</td>
#                         <td id="T_ca632132_3791_11eb_bb22_f2189821d74crow2_col2" class="data row2 col2" >0.565440</td>
#                         <td id="T_ca632132_3791_11eb_bb22_f2189821d74crow2_col3" class="data row2 col3" >0.726754</td>
#                         <td id="T_ca632132_3791_11eb_bb22_f2189821d74crow2_col4" class="data row2 col4" >0.086420</td>
#                         <td id="T_ca632132_3791_11eb_bb22_f2189821d74crow2_col5" class="data row2 col5" >0.052863</td>
#             </tr>
#             <tr>
#                         <th id="T_ca632132_3791_11eb_bb22_f2189821d74clevel0_row3" class="row_heading level0 row3" >RandomForestClassifier</th>
#                         <td id="T_ca632132_3791_11eb_bb22_f2189821d74crow3_col0" class="data row3 col0" >0.831642</td>
#                         <td id="T_ca632132_3791_11eb_bb22_f2189821d74crow3_col1" class="data row3 col1" >0.906344</td>
#                         <td id="T_ca632132_3791_11eb_bb22_f2189821d74crow3_col2" class="data row3 col2" >0.898243</td>
#                         <td id="T_ca632132_3791_11eb_bb22_f2189821d74crow3_col3" class="data row3 col3" >0.870383</td>
#                         <td id="T_ca632132_3791_11eb_bb22_f2189821d74crow3_col4" class="data row3 col4" >0.867133</td>
#                         <td id="T_ca632132_3791_11eb_bb22_f2189821d74crow3_col5" class="data row3 col5" >0.769231</td>
#             </tr>
#             <tr>
#                         <th id="T_ca632132_3791_11eb_bb22_f2189821d74clevel0_row4" class="row_heading level0 row4" >GradientBoostingClassifier</th>
#                         <td id=

# %%
sns.lineplot(data=f1_all.transpose(), markers=True)
plt.xticks(rotation='60', fontsize=14)
plt.yticks(fontsize=14)
plt.legend(loc='best')
plt.title('F1 Score of ML models (TF-IDF)', fontsize=18);

# Repeat this for CountVectorizer as well

# %%
f1_all.to_csv('./data/output/f1_scores_countvectorizer_results.csv')

# %% [markdown]
# ## 6. Ensemble Model Building

# %% [markdown]
# Idea here is to use GridSearch to find the most optimize paramters for the two top models from above:
# - **SVC with TfidfVectorizer**
# - **MLP with CountVectorized**
#
# Then use a VotingClassifier with both enzemble models

# %%
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler

# %%
SVCpipe = Pipeline([('scale', StandardScaler(with_mean=False)),
                   ('SVC',LinearSVC())])

# Gridsearch to determine the value of C
param_grid = {'SVC__C':np.arange(0.01,100,10)}
linearSVC = GridSearchCV(SVCpipe,param_grid,cv=5,return_train_score=True)


# Split the data into X and y data sets
X = data_toxic_balanced.comment_text
y = data_toxic_balanced['toxic']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Initiate a vectorizer
tfv = TfidfVectorizer(ngram_range=(1,1), stop_words='english')

X_train_fit = tfv.fit_transform(X_train)  # Convert the X data into a document term matrix dataframe
X_test_fit = tfv.transform(X_test)  # Converts the X_test comments into Vectorized format

# grid_clf = GridSearchCV(LinearSVC() , {
#     'C' : [1.0,20.0,30.0],
#     'kernel' : ['rbf', 'linear']

# },cv = 5, return_train_score=False)

linearSVC.fit(X_train_fit, y_train)
print(linearSVC.best_params_)
# Out:
# /Users/cristobalza/opt/anaconda3/envs/santiago-projects/lib/python3.7/site-packages/sklearn/svm/_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# {'SVC__C': 0.01}

# %%
linearSVC.best_estimator_
# Out:
# Pipeline(steps=[('scale', StandardScaler(with_mean=False)),
#                 ('SVC', LinearSVC(C=0.01))])

# %% [markdown]
# ## 7. Test Model Results

# %% [markdown]
# Let's compare the different models so far with simple phrases and only choosing a feature to predict.

# %% [markdown]
# ##### SVC with TfidfVectorizer

# %%
X = data_toxic_balanced.comment_text
y = data_toxic_balanced['toxic']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Initiate a vectorizer
tfv = TfidfVectorizer(ngram_range=(1,1), stop_words='english')

X_train_fit = tfv.fit_transform(X_train)  # Convert the X data into a document term matrix dataframe
X_test_fit = tfv.transform(X_test)  # Converts the X_test comments into Vectorized format

model = LinearSVC()
clf = CalibratedClassifierCV(model) # in case of SVM Family
model = clf

# Train our SVM model with the X training data converted into Count Vectorized format with the Y training data
model.fit(X_train_fit, y_train)
model.predict(X_test_fit)
# Out:
# array([1, 1, 1, ..., 1, 0, 1])

# %%
# Sample Prediction
comment1 = ['You piece of shit']
comment2 = ["Luke, I'm your papacito and I hope the force be with you tomorrow can be or maybe not"]

comment1_vect = tfv.transform(comment1)
model.predict_proba(comment1_vect)[:,1]
# Out:
# array([0.99999201])

# %%
comment2_vect = tfv.transform(comment2)
model.predict_proba(comment2_vect)[:,1]
# Out:
# array([0.15119634])

# %% [markdown]
# ##### MLP with CountVectorized

# %%
X = data_toxic_balanced.comment_text
y = data_toxic_balanced['toxic']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Initiate vectorizer
tfv = CountVectorizer(ngram_range=(1,1), stop_words='english')

X_train_fit = tfv.fit_transform(X_train)  # Convert the X data into a document term matrix dataframe
X_test_fit = tfv.transform(X_test)  # Converts the X_test comments into Vectorized format

model = MLPClassifier()
# clf = CalibratedClassifierCV(model) # in case of SVM Family
# model = clf

# Train our SVM model with the X training data converted into Count Vectorized format with the Y training data
model.fit(X_train_fit, y_train)
model.predict(X_test_fit)
# Out:
# array([1, 1, 1, ..., 1, 0, 1])

# %%
# Sample Prediction
comment1 = ['You are a piece of shit']
comment2 = ["Luke, I'm your papacito and I hope the force be with you tomorrow can be or maybe not"]

comment1_vect = tfv.transform(comment1)
model.predict_proba(comment1_vect)[:,1]
# Out:
# array([0.99999201])

# %%
comment2_vect = tfv.transform(comment2)
model.predict_proba(comment2_vect)[:,1]
# Out:
# array([0.15119634])
